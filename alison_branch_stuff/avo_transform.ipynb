# %%
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Reading our dataset 'avocado.csv' and printing a preview:
avocado_data = pd.read_csv('Data/avocado.csv')
avocado_data.head()
# Out:
#        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  12/27/15          1.33      64236.62  1036.74   54454.85   48.16
# 1  12/20/15          1.35      54876.98   674.28   44638.81   58.33
# 2  12/13/15          0.93     118220.22   794.70  109149.67  130.50
# 3   12/6/15          1.08      78992.15  1132.00   71976.41   72.58
# 4  11/29/15          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
list(avocado_data.columns)
# Out:
# ['Date',
#  'AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region']

# %%
#dropping dupliates of dates and regions 
avo_data_clean = avocado_data.drop_duplicates(['Date','region'])
avo_data_clean
# Out:
#           Date  AveragePrice  Total Volume       4046       4225      4770  \
# 0     12/27/15          1.33      64236.62    1036.74   54454.85     48.16
# 1     12/20/15          1.35      54876.98     674.28   44638.81     58.33
# 2     12/13/15          0.93     118220.22     794.70  109149.67    130.50
# 3      12/6/15          1.08      78992.15    1132.00   71976.41     72.58
# 4     11/29/15          1.28      51039.60     941.48   43838.39     75.78
# ...        ...           ...           ...        ...        ...       ...
# 9121    2/4/18          0.76    1272039.80  531469.08  368948.26  13078.20
# 9122   1/28/18          0.85     957086.16  479147.93  179489.19   7314.98
# 9123   1/21/18          0.84    1020913.20  505263.29  177911.40   9468.95
# 9124   1/14/18          0.90     950954.60  463945.73  188126.02  11227.47
# 9125    1/7/18          0.88     880266.52  436282.38  178669.53   9467.11
#
# ...

# %%
#print to csv with no index
avo_data_clean.to_csv('Data/avocado_cleaned.csv', index=False)
